# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from astropy.io import fits
from astropy import wcs
from astropy.coordinates import SkyCoord
from astropy import units as u

from IPython.display import Image
from skimage.io import imread

from toasty import toast, cartesian_sampler, normalizer

# %%
picture = imread('hubble_nebula_ngc_2818.png')
picture.shape
# Out:
# (1207, 2145, 3)

# %%
picture = picture[:1072,:2144,]
picture.shape
# Out:
# (1072, 2144, 3)

# %%
picture[500][1075]
# Out:
# array([  0, 139, 115], dtype=uint8)

# %%
plt.imshow(picture)

# %%
sampler = cartesian_sampler(picture)
output = 'toasts/nebula2'
depth = 8  
toast(sampler, depth, output, base_level_only=True, ra_range=[210.3,211],dec_range=[54,55.6])

# %%
Image(filename="toasts/nebula/0/0/0_0.png")

# %%
sky = imread('sky.png')
sky.shape
# Out:
# (1500, 3000, 3)

# %%
plt.imshow(sky)

# %%
sampler = cartesian_sampler(sky)
output = 'toasts/sky'
depth = 4  
toast(sampler, depth, output)

# %%
Image(filename="toasts/sky/1/0/0_0.png")

# %%
mars = imread('mars.jpg')
mars.shape
# Out:
# (512, 1024, 3)

# %%
plt.imshow(mars)

# %%
sampler = cartesian_sampler(mars)
output = 'toasts/mars2'
depth = 8
toast(sampler, depth, output, base_level_only=True, ra_range=[210.3,211],dec_range=[54,55.6])
# Out:
# [ 3.64846146  3.65718256  3.67550476  3.66482413]
# [ 3.64846146  3.65718256  3.67550476  3.66482413]
# 8 86 150
#
# [ 3.65718256  3.66618656  3.68469987  3.67550476]
# [ 3.65718256  3.66618656  3.68469987  3.67550476]
# 8 87 150
#
# [ 3.67550476  3.68469987  3.70279538  3.69144373]
# [ 3.67550476  3.68469987  3.70279538  3.69144373]
# 8 87 151
#
# [ 3.6472471   3.65644742  3.67559813  3.66618656]
# [ 3.6472471   3.65644742  3.67559813  3.66618656]
# 8 88 149
#
# [ 3.66618656  3.67559813  3.6943093   3.68469987]
# [ 3.66618656  3.67559813  3.6943093   3.68469987]
# 8 88 150
#
# [ 3.67559813  3.68532904  3.70423478  3.6943093 ]
# [ 3.67559813  3.68532904  3.70423478  3.6943093 ]
# 8 89 150
